# %% [markdown]
# Hier ist eine **verständliche Zusammenfassung des Kapitels 4 „Rotating Magnetic Fields“** – ohne Formeln, nur zur inhaltlichen Orientierung:
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ## ⚙️ **4.1 Grundprinzipien**
#
# Dieses Kapitel erklärt die physikalischen Grundlagen, wie **elektrische Maschinen** (Motoren & Generatoren) funktionieren.
# In solchen Maschinen entstehen Spannungen durch sich **ändernde magnetische Flüsse** – entweder weil:
#
# * Spulen durch ein Magnetfeld **gedreht** werden (Generatorprinzip), oder
# * das **Magnetfeld selbst rotiert** (Motorprinzip).
#
# **Armaturwicklung (Armature winding):**
#
# * Eine Gruppe von Spulen, die elektrische Energie überträgt.
# * Bei **AC-Maschinen** (Wechselstrommaschinen) → auf dem **Stator** (stehender Teil).
# * Bei **DC-Maschinen** (Gleichstrommaschinen) → auf dem **Rotor** (drehender Teil).
# * **Feldwicklungen** erzeugen das Magnetfeld (entweder mit Gleichstrom oder Permanentmagneten).
#
# Zur Minimierung von Verlusten werden **laminierte Bleche** (dünne, elektrisch isolierte Schichten aus Spezialstahl) verwendet, um **Wirbelströme** zu reduzieren.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ## ⚡ **4.2 Arten von Maschinen**
#
# ### 🔸 **Synchronmaschinen (SynM)**
#
# * Das Magnetfeld des Rotors dreht sich **synchron** (gleich schnell) wie das magnetische Feld des Stators.
# * Wird häufig als **Generator** eingesetzt (z. B. in Kraftwerken).
# * Die Rotordrehzahl hängt direkt von der **Frequenz** (z. B. 50 Hz) und der **Polzahl** ab.
#   → Beispiel: 2 Pole → 3000 U/min bei 50 Hz.
# * Mehr Pole = langsamere Drehzahl, daher werden langsame Turbinen (z. B. Wasserkraft) mit vielen Polen gebaut.
#
# **Aufbau:**
#
# * Feldwicklung (DC) → Rotor
# * Armaturwicklung (AC) → Stator
#
# ### 🔸 **Induktionsmaschinen (IM)**
#
# * Kein direkter Stromanschluss am Rotor → **Induktionswirkung** erzeugt Strom im Rotor.
# * Der Rotor läuft **etwas langsamer** als das Drehfeld → sogenannter **Schlupf**.
# * Sehr robust, günstig und weit verbreitet (z. B. in Industrieantrieben).
# * Das Prinzip ist ähnlich wie beim **Transformator**, nur dass sich hier das Magnetfeld bewegt.
#
# ### 🔸 **Gleichstrommaschinen (DC)**
#
# * Feldwicklung: am **Stator** (erzeugt konstantes Magnetfeld).
# * Armaturwicklung: am **Rotor** mit **Kommutator** (mechanischer Gleichrichter).
# * Der Kommutator sorgt dafür, dass die Ausgangsspannung immer in **eine Richtung** fließt (Gleichspannung).
# * Das Drehmoment entsteht – wie bei AC-Maschinen – durch die **Ausrichtung zweier Magnetfelder**.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ## 🧲 **4.3 Magnetomotorische Kraft (MMF)**
#
# MMF beschreibt die „treibende Kraft“ des Magnetfeldes, ähnlich wie Spannung bei elektrischem Strom.
#
# ### 🔹 **Verteilte Wicklungen**
#
# In realen Maschinen sind Wicklungen **über viele Schlitze verteilt**, um:
#
# * die magnetische Feldverteilung zu **glätten**,
# * **Oberwellen** (Störungen) zu verringern,
# * und eine **sinusförmige Feldverteilung** zu erzeugen.
#
# Dafür wird ein **Wicklungsfaktor (kw)** verwendet, der beschreibt, wie effektiv die Wicklung das Feld erzeugt (meist 0,85–0,95).
#
# Das Ergebnis ist ein **gleichmäßiges Drehfeld**, das als rotierende magnetische Welle verstanden werden kann.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ## 🔄 **4.4 Rotierende Magnetfelder**
#
# ### 🔸 **Einphasen-System**
#
# Eine einzelne Wechselstromwicklung erzeugt ein **wechselndes**, aber **nicht rotierendes** Feld.
# Man kann dieses Feld als Überlagerung von zwei **entgegengesetzt drehenden Feldern** betrachten:
#
# * ein positives (nützliches) Drehfeld,
# * und ein negatives (unerwünschtes) Drehfeld.
#   → Deshalb können Einphasenmotoren **nicht selbst anlaufen**, ohne Zusatzwicklung oder Hilfsschaltung.
#
# ### 🔸 **Mehrphasen-System (z. B. Dreiphasen)**
#
# * Drei Wicklungen, um 120° versetzt, erzeugen **drei sinusförmige Ströme**, die ebenfalls um 120° zeitlich verschoben sind.
# * Diese Ströme erzeugen **ein einziges, rotierendes Magnetfeld konstanter Stärke**.
# * Dieses Feld dreht sich mit der **Synchronfrequenz** (abhängig von Polzahl und Netzfrequenz).
#   → Dieses **Drehfeldprinzip** ist die Grundlage aller modernen AC-Motoren und -Generatoren.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ## 🌀 **4.5 Erzeugte Spannung**
#
# Wenn sich der Rotor im Magnetfeld bewegt, wird durch die **Änderung des magnetischen Flusses** eine Spannung induziert.
#
# * Die Spannung hängt von der **Drehgeschwindigkeit**, der **Polzahl** und der **Flussdichte** ab.
# * Bei konstantem Fluss ist die induzierte Spannung direkt proportional zur Drehzahl.
#
# Die **Frequenz der erzeugten Spannung** wird durch die Drehzahl bestimmt:
# → Je schneller der Rotor, desto höher die Frequenz.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ## ⚙️ **4.6 Drehmoment in Maschinen**
#
# Das **elektromagnetische Drehmoment** entsteht aus der **Wechselwirkung zweier Magnetfelder**:
#
# 1. des Stators (durch Strom in der Wicklung),
# 2. des Rotors (durch Strom oder Dauermagnet).
#
# Das Drehmoment strebt danach, die beiden Felder **aufeinander auszurichten** (ähnlich wie zwei Magnete, die sich drehen, um sich anzuziehen).
#
# ### Zwei Betrachtungsweisen:
#
# * **Schaltkreis-Modell (Coupled Circuit View):** betrachtet Ströme und Induktivitäten.
# * **Feld-Modell:** betrachtet die physikalischen Magnetfelder und deren Ausrichtung.
#
# Das maximale Drehmoment tritt auf, wenn die beiden Felder **90° phasenverschoben** sind.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ## 🧮 **4.7 Magnetische Sättigung**
#
# Wenn der magnetische Fluss im Eisen zu stark wird, erreicht das Material seine **Sättigung**:
#
# * Die Magnetisierbarkeit nimmt ab.
# * Die Effizienz sinkt, weil mehr Energie als Wärme verloren geht.
#
# Zur Modellierung solcher Effekte wird in Berechnungen oft der **effektive Luftspalt** vergrößert, um die reale Sättigung zu berücksichtigen.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ## 🔍 **4.8 Streufluss (Leakage Flux)**
#
# Nicht alle magnetischen Feldlinien tragen zur Energieumwandlung bei.
#
# * Ein Teil des Flusses bleibt **in den Wicklungen selbst** → sogenannter **Streufluss**.
# * Nur der **gemeinsame Fluss (Mutual Flux)** zwischen Rotor und Stator erzeugt nutzbares Drehmoment.
#
# Streufluss beeinflusst:
#
# * die **Selbstinduktanz** der Spulen,
# * und kann **Leistungsverluste** verursachen.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ## 🧠 **Kernidee**
#
# Das Kapitel zeigt, **wie rotierende magnetische Felder** entstehen und wie sie **elektromechanische Energieumwandlung** ermöglichen:
#
# | Prinzip                                  | Beschreibung                                                                       |
# | ---------------------------------------- | ---------------------------------------------------------------------------------- |
# | **Wechselnde Ströme → rotierendes Feld** | In Mehrphasenmaschinen entstehen Magnetfelder, die sich im Kreis bewegen.          |
# | **Rotor folgt Drehfeld**                 | Erzeugt Drehmoment (Motor) oder induzierte Spannung (Generator).                   |
# | **Synchronität**                         | Bei SynM rotiert der Rotor mit dem Feld; bei IM etwas langsamer (Schlupf).         |
# | **Feldkopplung**                         | Je stärker und gleichmäßiger die magnetische Kopplung, desto höher das Drehmoment. |

# %% [markdown]
# ![image.png](attachment:image.png)
