# %% [markdown]
# * **Ø 130 mm:** ca. **2000–3000 U/min**
# * **Ø 200 mm:** ca. **1500–2000 U/min**
# * **Ø 300 mm:** ca. **1000–1500 U/min**
# * **Ø 400 mm:** ca. **700–1000 U/min**
# * **Ø 500 mm:** ca. **500–700 U/min**
#
# 👉 **Faustformel:**
# $$
# \text{Drehzahl (U/min)} = \frac{6000}{\text{Werkstückdurchmesser (cm)}}
# $$

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #f1c40f;">

# %% [markdown]
# ## 🔧 **Ziel des Versuchs**
#
# In **Task 2** („Bau einer Drehbank“) sollt ihr **ein funktionierendes Antriebssystem** für eine Drehbank (**Lathe**) **selbst aufbauen**.
# Dazu verwendet ihr **einen Frequenzumrichter (Inverter)** und **eine Asynchronmaschine (Induction Machine, IM)**.
# 👉 Im Gegensatz zu Versuch 1 wird **kein PLC (Speicherprogrammierbare Steuerung)** benutzt.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
#
# ## 🎯 **Lernziele**
#
# Nach Abschluss des Versuchs sollt ihr verstehen:
#
# * wie man eine einfache Antriebssteuerung mit Umrichter und Asynchronmotor aufbaut,
# * wie man **Ein- und Ausgänge** eines Umrichters für externe Steuerung nutzt,
# * wie man **Parameter** eines Umrichters **konfiguriert**.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
#
# ## 📚 **Vorbereitung vor dem Labor**
#
# Vor dem Versuch müsst ihr **drei Dinge recherchieren**:
#
# 1. Welche **Drehzahlen** sind für das **Drechseln von Holz** mit einem **Durchmesser von 130 mm bis 500 mm** üblich?
# 2. Wie **hängt die Drehzahl vom Werkstückdurchmesser** ab (also: wie verändert sich die optimale Drehzahl mit dem Durchmesser)?
# 3. Wie würdet ihr **sechs verschiedene Drehzahlen** gleichmäßig über diesen Bereich **verteilen**?
#
# ➡️ Diese Vorbereitung hilft euch später bei der Auswahl realistischer Drehzahlen für eure Drehbank.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
#
# ## 🧩 **Aufgaben (Tasks)**
#
# ### **1️⃣ Erste Aufgabe**
#
# Baut ein einfaches Antriebssystem, das die **Grundfunktionen einer typischen Drehbank** besitzt:
#
# 1. **Sieben (7) feste Drehzahlen** (diskrete Geschwindigkeiten),
# 2. **Fehler- und Warnanzeigen** vom Umrichter,
# 3. Einen **Ein/Aus-Schalter**.
#
# 👉 Ziel: Eine Drehbank, die sich über verschiedene feste Drehzahlen betreiben lässt und Fehler meldet.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
#
# ### **2️⃣ Zweite Aufgabe**
#
# Aufbauend auf dem ersten System sollt ihr **zusätzliche Funktionen** einbauen:
#
# 1. **Drei (3) variable Drehzahlen** (also einstellbare Geschwindigkeiten),
# 2. Wieder **Fehler- und Warnanzeigen**,
# 3. Einen **analogen Eingang**, über den die Drehzahl **stufenlos** verändert werden kann,
# 4. Einen **Ein/Aus-Schalter**,
# 5. Einen **analogen Ausgang**, der die **aktuelle Drehzahl als Stromsignal (4–20 mA)** ausgibt,
# 6. Eine Möglichkeit (z. B. Schalter oder Taster), um zwischen **zwei Parametersätzen** mit unterschiedlichen **dynamischen Eigenschaften** umzuschalten.
#
# 👉 Ziel: Eine fortgeschrittene Drehbanksteuerung, bei der ihr die Drehzahl flexibel einstellen und Parameter umschalten könnt.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
#
# ### **3️⃣ Dritte Aufgabe (optional)**
#
# Ihr dürft das System **frei weiterentwickeln** – zum Beispiel:
#
# * zusätzliche Sicherheitselemente,
# * digitale Anzeige der Drehzahl,
# * andere Steuerkonzepte usw.
#
# Das bleibt euch überlassen.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
#
# ## 🧾 **Versuchsbericht**
#
# Nach dem Versuch müsst ihr einen **Laborbericht** abgeben (innerhalb von **2 Wochen** nach dem Labortermin, über **SAKAI**).
# Der Bericht sollte Folgendes enthalten:
#
# | Abschnitt                  | Inhalt                                               |
# | -------------------------- | ---------------------------------------------------- |
# | **Deckblatt**              | Titel, Namen, Matrikelnummern, Modul                 |
# | **Abstract**               | Kurze Zusammenfassung (100–200 Wörter)               |
# | **Einleitung**             | Hintergrund, Motivation, Theorie, Literaturrecherche |
# | **Materialien & Methoden** | Aufbau, Geräte, Schaltung, Vorgehen                  |
# | **Ergebnisse**             | Messergebnisse, Diagramme, Tabellen                  |
# | **Diskussion & Fazit**     | Auswertung, Interpretation, Probleme, Verbesserungen |
# | **Quellen**                | Literaturangaben im **IEEE-Zitationsstil**           |

# %% [markdown]
# <hr style="border: none; border-top: 5px solid #3498db;">

# %% [markdown]
# ## ⚙️ **Ziel der zweiten Aufgabe**
#
# Du sollst dein Lathe-System erweitern, sodass:
#
# * es **drei variable Drehzahlen** hat,
# * sich die **Drehzahl auch analog (stufenlos)** einstellen lässt,
# * der **Ist-Wert der Drehzahl** als **4–20 mA-Signal** ausgegeben wird,
# * du zwischen **verschiedenen Parameter-Sätzen** umschalten kannst (z. B. „weich“ vs. „dynamisch“),
# * und der Umrichter weiterhin **Fehler- und Warnsignale** anzeigen kann.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ## 🧰 **1️⃣ Benötigte Komponenten**
#
# | Komponente                              | Funktion                                             |
# | --------------------------------------- | ---------------------------------------------------- |
# | **Inverter (Frequenzumrichter)**        | Steuert den Motor und erhält Ein-/Ausgänge           |
# | **Induction Motor (IM)**                | Antriebsmotor der Drehbank                           |
# | **Schalter / Taster**                   | Für ON/OFF, Geschwindigkeitswahl, Parameterwahl      |
# | **Potentiometer** (z. B. 10 kΩ)         | Analoger Eingang zur stufenlosen Drehzahlregelung    |
# | **Analoge Messeinheit oder Multimeter** | Zum Überprüfen des 4–20 mA-Signals                   |
# | **Signalleuchten / LEDs**               | Anzeige von Fehlern oder Warnungen                   |
# | **Versorgung (230 V oder 400 V)**       | Je nach Motor/Inverter-Typ                           |
# | **Kabelsatz**                           | Verbindung zwischen Inverter, Motor, Bedienelementen |
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ## 🔌 **2️⃣ Grundaufbau**
#
# 1. **Motor–Umrichter–Netz** anschließen:
#
#    * Netz → Umrichter → Motor (wie in Versuch 1).
#    * Achte auf die richtige Phasenfolge.
#
# 2. **Steuersignale verdrahten:**
#
#    * Digitale Eingänge (DI1, DI2, DI3 …) für Schalter/Taster,
#    * Analoger Eingang (AI1) für Potentiometer,
#    * Analoger Ausgang (AO1) für 4–20 mA-Signal.
#
# 3. **Fehlerausgänge (DO)** an LED oder Kontrolllampe anschließen.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ## 🧠 **3️⃣ Umrichter-Parametrierung**
#
# Die genauen Bezeichnungen hängen vom Hersteller ab (z. B. ABB, Siemens, Lenze), aber das Prinzip ist immer gleich:
#
# | Funktion                        | Parameter / Einstellung                   | Erklärung                                                                                                |
# | ------------------------------- | ----------------------------------------- | -------------------------------------------------------------------------------------------------------- |
# | **Digitale Eingänge (DI1–DI3)** | z. B. „Preset speed selection“            | Jeder Eingang steht für eine feste Drehzahl (3 variable Geschwindigkeiten)                               |
# | **Analoger Eingang (AI1)**      | „Speed reference (0–10 V oder 4–20 mA)“   | Hier kommt dein Potentiometer-Signal rein – ermöglicht stufenlose Drehzahlsteuerung                      |
# | **Analoger Ausgang (AO1)**      | „Output: motor speed feedback (4–20 mA)“  | Gibt die aktuelle Drehzahl als Stromsignal aus                                                           |
# | **Parameter Set 1 / 2**         | „Parameter switching“ oder „Macro select“ | Hier kannst du über einen Eingang zwischen zwei Parametern umschalten (z. B. Rampenzeit, Beschleunigung) |
# | **Fehlerausgang (DO)**          | „Fault relay / warning output“            | Schaltet LED bei Fehler oder Warnung                                                                     |
# | **ON/OFF Eingang**              | „Run/Stop command“                        | Steuert das Starten/Stoppen des Motors                                                                   |
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ## ⚡ **4️⃣ Funktionsprüfung**
#
# Teste die Funktionen nacheinander:
#
# 1. **ON/OFF-Schalter:**
#
#    * Prüfen, ob Motor startet und stoppt.
#
# 2. **Drehzahlstufen (3 variable Geschwindigkeiten):**
#
#    * Über digitale Eingänge die Geschwindigkeit wechseln.
#    * Beobachte die Motordrehzahl am Display oder Tachometer.
#
# 3. **Analoge Steuerung:**
#
#    * Mit Potentiometer die Drehzahl stufenlos verändern.
#    * Prüfe, ob die Spannungs- oder Stromwerte korrekt skalieren (z. B. 0 V → 0 rpm, 10 V → max rpm).
#
# 4. **4–20 mA-Ausgang:**
#
#    * Multimeter in Strommessmodus schalten.
#    * Prüfen: 4 mA bei Stillstand, 20 mA bei Nenndrehzahl.
#
# 5. **Parameterumschaltung:**
#
#    * Schalte per Eingang zwischen zwei Datensätzen (z. B. Parameter Set 1 = weiche Beschleunigung, Set 2 = schnelle).
#    * Beobachte das geänderte Verhalten beim Anfahren und Bremsen.
#
# 6. **Fehleranzeige:**
#
#    * Trenne kurzzeitig ein Signal oder überlaste leicht den Motor (vorsichtig!).
#    * LED sollte aufleuchten → Fehlerausgang funktioniert.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ## 🧾 **5️⃣ Dokumentation / Bericht**
#
# Im Laborbericht solltest du Folgendes beschreiben:
#
# * **Schaltplan:** Welche Eingänge/Ausgänge wofür genutzt werden,
# * **Parametertabelle:** Welche Parameter du im Umrichter gesetzt hast,
# * **Messungen:** Drehzahlwerte, analoge Ausgangsströme, Reaktionszeiten,
# * **Erklärung:** Wie die verschiedenen Parameter das Verhalten verändern (z. B. Rampenzeit, Momentbegrenzung),
# * **Fazit:** Ob alle Anforderungen erfüllt wurden und welche Verbesserungen du vorschlägst.
