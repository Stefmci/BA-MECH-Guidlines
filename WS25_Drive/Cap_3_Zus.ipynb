# %% [markdown]
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ### 🧭 **3.1 Grundbegriffe**
#
# Dieses Kapitel führt in den Prozess der **elektromechanischen Energieumwandlung** ein – also wie elektrische, magnetische und mechanische Energie ineinander umgewandelt werden.
# Je nach Anwendung unterscheidet man drei Gerätearten:
#
# 1. **Transducer** – Mess- oder Steuergeräte (z. B. Mikrofone, Sensoren).
# 2. **Reactionary Devices** – Geräte, die Bewegung erzeugen, aber keine dauerhafte Rotation (z. B. Relais, Elektromagnete).
# 3. **Continuous Devices** – Geräte mit kontinuierlicher Bewegung, also Motoren und Generatoren.
#
# Der Fokus liegt hier auf Systemen, die **magnetische Felder** als Energieübertragungsmedium verwenden (wie Motoren oder Relais).
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ### ⚡ **3.2 Kräfte und Drehmoment im Magnetfeld**
#
# Die Bewegung elektrisch geladener Teilchen in elektrischen und magnetischen Feldern erzeugt Kräfte.
# Wichtig:
#
# * Im **elektrischen Feld** wirkt die Kraft in Feldrichtung.
# * Im **magnetischen Feld** wirkt die Kraft **senkrecht** zur Bewegungsrichtung und zur Feldrichtung (→ „rechte Hand Regel“).
#
# In Maschinen wirken solche Kräfte auf Leiter oder Materialien, was zu Bewegung oder Drehmoment führt.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ### 🔋 **3.3 Theorie der Energiebilanz**
#
# In realen Maschinen betrachtet man meist **nicht jede einzelne Kraft**, sondern die **Gesamtenergieübertragung**:
#
# * Elektrische Energie → magnetische Energie → mechanische Energie (und umgekehrt).
# * Dabei entstehen Verluste (z. B. Wärme durch Widerstand, Reibung).
# * Diese Verluste kann man mathematisch ausklammern, um die „reine“ Energieumwandlung zu verstehen.
#
# So lässt sich die Maschine als **verlustloses System** darstellen, in dem Energie zwischen elektrischen und mechanischen Größen über das **magnetische Feld** fließt.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ### 🧩 **3.4 Energie in einem einfach erregten Magnetkreis**
#
# Bei Geräten wie Relais entsteht Energie im **Luftspalt** zwischen zwei magnetischen Teilen.
# Dieser Luftspalt ist entscheidend, da dort das meiste magnetische Feld gespeichert ist.
# Die **induktive Kopplung** zwischen Strom und Magnetfeld hängt von der **Geometrie** (z. B. Spulenabstand, Luftspaltgröße) ab.
# → Verändert sich der Abstand, verändert sich die gespeicherte Energie – daraus entstehen **Kräfte** oder **Drehmomente**.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ### ⚙️ **3.5 Bestimmung von Kräften und Drehmoment**
#
# Wenn man weiß, wie viel Energie im Magnetfeld gespeichert ist, kann man daraus berechnen:
#
# * Die **Kraft**, wenn sich etwas linear bewegt (z. B. ein Kolben),
# * oder das **Drehmoment**, wenn sich etwas dreht (z. B. ein Rotor).
#
# Wichtig:
#
# * Die magnetische Energie hängt vom **Strom** und von der **Position** (oder dem Winkel) ab.
# * Diese Beziehung nennt man den **Energieansatz**.
# * Alternativ kann man auch den sogenannten **Co-Energy-Ansatz** benutzen (siehe unten).
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ### 🔄 **3.6 Co-Energy (Gegenenergie)**
#
# Die **Co-Energy** ist eine rechnerische Hilfsgröße, die bei der Berechnung von Kräften oder Drehmomenten oft einfacher zu handhaben ist.
# Beide – Energie und Co-Energy – führen zum selben Ergebnis, nur über unterschiedliche Rechenwege.
#
# * In linearen Systemen (z. B. ohne Sättigung) sind Energie und Co-Energy **gleich groß**.
# * In nichtlinearen Systemen (z. B. mit magnetischer Sättigung) unterscheiden sie sich, aber beide beschreiben denselben physikalischen Vorgang.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ### ⚖️ **3.7 Einfach und mehrfach erregte Systeme**
#
# * **Einfach erregt** = eine Spule oder Wicklung (z. B. Relais).
# * **Mehrfach erregt** = mehrere Wicklungen (z. B. Stator und Rotor in einem Motor).
#
# Bei mehrfach erregten Systemen entsteht Drehmoment aus zwei Effekten:
#
# 1. **Wechselseitige (mutuale) Induktion** → Rotor und Stator ziehen sich an, um sich auszurichten.
# 2. **Reluktanzmoment** → Das System versucht, den magnetischen Widerstand zu verringern (das Magnetfeld nimmt den „leichtesten Weg“).
#
# Diese beiden Drehmomente (Mutual + Reluctance) bilden das **Gesamtdrehmoment** der Maschine.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ### 💡 **Beispiel: Buchholz-Relais**
#
# Zum Abschluss wird ein praktisches Beispiel genannt:
# Das **Buchholz-Relais** ist ein Schutzgerät in Transformatoren, das Gasbildung im Öl erkennt – ein Hinweis auf innere Fehler.
# → Es löst einen Alarm oder eine Abschaltung aus, wenn etwas nicht stimmt.
#
# <hr style="border: none; border-top: 1px solid #f1c40f;">
#
# ### 🧠 **Kernidee des Kapitels**
#
# Elektromechanische Energieumwandlung funktioniert durch das **Wechselspiel von Strom, Magnetfeld und Bewegung**.
# Energie fließt zwischen:
#
# * Elektrischer Seite (Spule, Strom),
# * Magnetischem Feld (Speicher),
# * Mechanischer Seite (Kraft, Bewegung).
#
# Die **Energie- und Co-Energie-Methoden** sind mathematische Werkzeuge, um diese Kräfte zu verstehen und zu berechnen – sie sind die Basis für das Design von Motoren, Generatoren und Aktoren.

# %% [markdown]
# ![image.png](attachment:image.png)
