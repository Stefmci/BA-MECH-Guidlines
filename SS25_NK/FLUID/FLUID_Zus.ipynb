# %% [markdown]
# <hr style="border: none; border-top: 5px solid #3498db;">

# %% [markdown]
# # 👉 Altklausur

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #2ecc71;">

# %% [markdown]
# ## 📘 Aufgabe 2 Blatt Papier
#
# ### 1️⃣ Ausgangspunkt: **Bernoulli-Gleichung allgemein**
#
# Für eine stationäre, reibungsfreie Strömung gilt entlang einer Stromlinie:
#
# $$
# p + \frac{1}{2} \rho v^2 + \rho g h = \text{konstant}
#
# $$
# Dabei ist
#
# * $(p)$: statischer Druck
# * $(\rho)$: Dichte der Luft
# * $(v)$: Strömungsgeschwindigkeit
# * $(h)$: Höhe
# * $(\rho g h)$: hydrostatischer Druckanteil
#
#
#
# ### 2️⃣ Vereinfachung für die Situation
#
# In deinem Fall pustest du **horizontal über das Blatt**.
# → Die Höhe (h) ändert sich praktisch **nicht**, also fällt der Term $(\rho g h)$ raus.
# Damit bleibt:
#
# $$
# p + \frac{1}{2} \rho v^2 = \text{konstant}
# $$
#
# Das bedeutet:
# **Wenn die Geschwindigkeit steigt, sinkt der Druck** – und umgekehrt.
#
#
#
# ### 3️⃣ Vergleich zweier Punkte
#
# Wir vergleichen zwei Bereiche:
#
# | Bereich                             | Geschwindigkeit | Druck                        |
# | --- | --- | ---- |
# | **(1)** ruhende Luft (weit weg)     | (v_1 = 0)       | $(p_1 = p_0) (Umgebungsdruck) $|
# | **(2)** Luft direkt über dem Papier | (v_2 = v)       | $(p_2 = p_{\text{oben}})$      |
#
# Setzen wir das in die vereinfachte Bernoulli-Gleichung ein:
#
# $$
# p_1 + \frac{1}{2}\rho v_1^2 = p_2 + \frac{1}{2}\rho v_2^2
# $$
#
#
#
# ### 4️⃣ Einsetzen und umstellen
#
#
# $$p_0 + \frac{1}{2}\rho (0)^2 = p_{\text{oben}} + \frac{1}{2}\rho v^2
# $$
#
# $$
# \Rightarrow \quad p_{\text{oben}} = p_0 - \frac{1}{2}\rho v^2
#
# $$
#
#
# ### 5️⃣ Interpretation
#
# * Der Term $( \frac{1}{2}\rho v^2 )$ ist der **dynamische Druck** der Strömung.
# * Wenn die Luft über dem Papier schnell strömt, wird **statischer Druck** in **Bewegungsenergie** umgewandelt.
# * Dadurch ist $(p_{\text{oben}})$ **kleiner als der Umgebungsdruck** $(p_0)$.
# * Unten bleibt der Druck $(p_{\text{unten}} \approx p_0)$.
# * Also:
#   $$
#   p_{\text{unten}} > p_{\text{oben}} \quad \Rightarrow \quad \text{Kraft nach oben.}
#   $$
#
#
#
# ### 🧭 Kurz gesagt
#
# Die Gleichung
#
# $$
# p_{\text{oben}} = p_0 - \frac{1}{2}\rho v^2
# $$
#
# kommt direkt aus **Bernoulli**, indem man zwei Punkte mit unterschiedlicher Geschwindigkeit, aber gleicher Höhe vergleicht.
# → Sie erklärt, warum das Blatt sich hebt, wenn du darüber pustest.

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #2ecc71;">

# %% [markdown]
# ## 🎯 Aufgaben Kapitel 2

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #2ecc71;">

# %% [markdown]
# <hr style="border: none; border-top: 5px solid #3498db;">
