# %% [markdown]
# <hr style="border: none; border-top: 5px solid #3498db;">

# %% [markdown]
# # 👉 Zusammenfassung – Teilklausur **Thermofluiddynamik** (Küper, SS 2025)
#
# **Datum der Klausur:** 23.06.2025 · **Zeit:** 10:45–12:15 · **Ort:** MCI
# **Lektor:** Dipl.-Ing. Malte Küper · **Studiengang:** BA-MECH-23 (Mechatronik, Design & Innovation)

# %% [markdown]
# **Notenschema:** ≥90%: 1 · ≥80%: 2 · ≥70%: 3 · ≥60%: 4 · <60%: 5
# **Erlaubte Hilfsmittel:** keine
# **Hinweise (Kurzfassung):** Nur Prüfungsblätter verwenden, Vorderseite beschreiben, keine Bleistifte/roten Stifte, Student Card auslegen.

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #2ecc71;">

# %% [markdown]
# ## 📘 Fragenteil 0 – *Gleichungen benennen* (Formelsammlung)
#
# - **Massenerhaltung (differentiell):**
#   $$\frac{\partial \rho}{\partial t} + \nabla \cdot (\rho \vec{v}) = 0$$
#
# - **Navier–Stokes (Impulsgleichung):**
#   $$\rho \left( \frac{\partial \vec{v}}{\partial t} + (\vec{v}\cdot\nabla)\vec{v} \right) = -\nabla p + \nabla \cdot \boldsymbol{\tau} + \rho \vec{g}$$
#
# - **Impulserhaltung (integral, Impulssatz):**
#   $$\oint_{\partial V} \rho \vec{v}\, v_n \, \mathrm{d}A + \oint_{\partial V} p \, \vec{n}\, \mathrm{d}A = \vec{F}_\text{n}$$
#
# - **Bernoulli (mit Verlust- und Unstetigkeitstermen, allgemein):**
#   $$p_1 + \tfrac{1}{2}\rho v_1^2 + \rho g z_1 = p_2 + \tfrac{1}{2}\rho v_2^2 + \rho g z_2 + \tfrac{1}{2}\rho \sum_i \zeta_i v_i^2 + \rho \int_{s_1}^{s_2} \frac{\mathrm{d}v}{\mathrm{d}t}\, \mathrm{d}s$$
#
# - **Kontinuität (integral):**
#   $$\rho_1 v_1 A_1 = \rho_2 v_2 A_2$$
#
# - **Euler-Gleichung der Turbomaschinen (Spezifische Arbeit):**
#   $$Y = u_2 c_{u2} - u_1 c_{u1}$$
#
# - **Ideale Gasgleichung:**
#   $$\frac{p}{\rho} = R T$$

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #2ecc71;">

# %% [markdown]
# ## 🧠 Fragenteil – Lösungen & Erklärungen
#
# ### 1) Terme der Navier–Stokes und reibungsfreie Strömung
# - **Akkumulation:** $$\rho \, \frac{\partial \vec{v}}{\partial t}$$ – lokale zeitliche Änderung des Impulses.
# - **Konvektiver Transport:** $$\rho\,(\vec{v}\cdot\nabla)\vec{v}$$ – Impulsmitnahme durch Strömung.
# - **Druckterm:** $$-\nabla p$$ – Antrieb/Abbremsung durch statischen Druckgradienten.
# - **Viskoser (molekularer) Transport:** $$\nabla\cdot\boldsymbol{\tau}$$ – Schubspannungen infolge Viskosität.
# - **Volumenkraft:** $$\rho\vec{g}$$ – z.B. Schwerkraft.
# → **Bei reibungsfreier (inviszider) Strömung** entfällt der **viskose Term** $$\nabla\cdot\boldsymbol{\tau}$$.
#
# ---
#
# ### 2) „Über ein Blatt pusten“ – wohin bewegt sich der überhängende Teil?
# Beim Anblasen der **Oberseite** nimmt dort die **Strömungsgeschwindigkeit** zu → der **statische Druck sinkt** (Bernoulli).
# Unterseite ~ Umgebungsdruck ⇒ **Druckdifferenz nach oben** ⇒ das **Blatt hebt sich an** (*oben*).
#
# ---
#
# ### 3) Schubspannung & Viskosität (Newtonsche Fluide)
# Für eine Scherströmung gilt **Newton’sches Gesetz**:
# $$\tau = \mu \, \frac{\mathrm{d}u}{\mathrm{d}y}$$
# $$\tau$$: Schubspannung, $$\mu$$: dynamische Viskosität, $$\frac{\mathrm{d}u}{\mathrm{d}y}$$: Geschwindigkeitsgradient normal zur Wand.
# **Linearer Zusammenhang** zwischen $$\tau$$ und Gradienten (bei Newton’schen Fluiden).
#
# ---
#
# ### 4) Laminar oder turbulent? (Flügel $$L_s=0{,}5\,\mathrm{m}$$, $$L_B=3\,\mathrm{m}$$, $$V_\infty=10\,\mathrm{m/s}$$, $$\nu=10\,\mathrm{mm^2/s}=1\cdot10^{-5}\,\mathrm{m^2/s}$$)
# $$\mathrm{Re} = \frac{V L_s}{\nu} = \frac{10 \cdot 0{,}5}{1\cdot10^{-5}} = 5\cdot 10^5$$
# **Große Re** → Grenzschicht **tendenziell turbulent** (insbesondere stromab der Anlaufstrecke).
#
# ---
#
# ### 5) Wärmeübergang: laminar vs. turbulent
# **Turbulent** ist der Wärmeübergang i.d.R. **größer**, da **Wirbel/Mischung** skalare Gradienten (Temperatur) verstärken → höhere **Nusselt-Zahl**.
#
# ---
#
# ### 6) Reynoldszahl – balancierte Transportmechanismen
# $$\mathrm{Re} = \dfrac{\text{Trägheits-/Konvektionseffekte}}{\text{Viskose Diffusion}}$$.
# Große Re → Konvektion dominiert; kleine Re → Viskosität dominiert.
#
# ---
#
# ### 7) Geschwindigkeitsprofile (gleicher Volumenstrom)
# - **Laminar:** „spitz“/parabolisch, Maximalgeschwindigkeit in der Mitte groß, Wandgradient klein.
# - **Turbulent:** „bauchig“/abgeflacht, **höherer Wandgradient** (→ größere Schubspannung), geringerer Spitzenwert.
#
# ---
#
# ### 8) Annahmen der *einfachen* Bernoulli-Gleichung
# - **Stationär**, **inkompressibel**, **reibungsfrei** (viskositätsfrei),
# - **entlang eines Stromfadens**, **ohne Wellen-/Shaft-Arbeit** und **ohne Wärmeübertragung** zwischen den Punkten.
#
# ---
#
# ### 9) Axialmaschine – Dreiecke, Verdichter oder Turbine?
# - **Geschwindigkeitsdreiecke**: Absolutgeschwindigkeit $$\vec{c}$$, Umfangsgeschwindigkeit $$\vec{u}$$, Relativgeschwindigkeit $$\vec{w}=\vec{c}-\vec{u}$$.
# - **Beurteilung über Wirbelkomponente** $$c_u$$: $$Y = u_2 c_{u2} - u_1 c_{u1}$$.
#   - **Turbine:** $$\;Y<0$$ (Strömung verrichtet Arbeit am Rotor: $$c_{u2}$$ typ. **kleiner/entgegengesetzt** zu $$c_{u1}$$).
#   - **Verdichter:** $$\;Y>0$$ (Rotor verrichtet Arbeit am Fluid: Zunahme von $$c_u$$).
# → Aus den skizzierten Dreiecken (gegeben) resultiert **$$Y<0$$** ⇒ **Turbine**.
#
# ---
#
# ### 10) Rohrsystem – Verlauf $$p_s$$ und $$p_t$$ bei reibungsbehafteter Strömung
# - **Totaldruck $$p_t$$**: nimmt **monoton ab** entlang der Strömung (Verluste).
# - **Statischer Druck $$p_s$$**: hängt von **Querschnittsänderungen** ab: in **Verengungen** sinkt $$p_s$$, in **Erweiterungen** steigt $$p_s$$ (bei gleichem $$p_t$$-Abfall).
# - Am **Ein-/Ausgang**: $$p_s \approx p_\mathrm{amb}$$.
#
# ---
#
# ### 11) „Inkompressible Strömungen sind divergenzfrei?“
# Ja, **für $$\rho=\mathrm{const.}$$** gilt aus der Kontinuität:
# $$\nabla\cdot \vec{v} = 0$$
# (Bei kompressiblen Flüssen kann $$\nabla\cdot\vec{v}\ne 0$$.)

# %% [markdown]
# <hr style="border: none; border-top: 5px solid #3498db;">

# %% [markdown]
# ## 🧩 Aufgabenteil – strukturierte Lösungen
#
# ### **Aufgabe 1: Schaufelgitter im Gitterwindkanal** *(inkompressibel, reibungsfrei)*
#
# **Gegeben:** $$v_{1x}>0$$, $$v_{1y}=0$$, $$\rho,\, b,\, t,\, p_1,\, p_2$$.
# **Gesucht:** Axialkomponente $$R_x$$ der resultierenden Kraft $$\vec{R}$$ auf das Gitter (Breite $$b$$, Teilung $$t$$).
# **Kontrollvolumen** entlang der Stromfäden, stationär.
#
# **a) Durchströmte Ränder**
# Nur **links** (Zuströmung) und **rechts** (Abströmung) werden durchströmt.
#
# **b) $$v_{2x}$$** (Massenerhaltung pro Teilung $$t$$, Breite $$b$$)
# Für inkompressible Strömung und gleiche effektive „Durchtrittsfläche“ (pro Pitch):
# $$\boxed{\,v_{2x} = v_{1x}\,}$$
#
# **c) $$v_{2y}$$** (Bernoulli 1 $$\to$$ 2, $$v_{1y}=0$$)
# $$\;p_1 + \tfrac12 \rho (v_{1x}^2) = p_2 + \tfrac12 \rho (v_{2x}^2 + v_{2y}^2)$$
# Mit $$v_{2x}=v_{1x}$$ folgt:
# $$\boxed{\,v_{2y} = \pm \sqrt{\tfrac{2}{\rho}(p_1 - p_2)}\,}$$
# (Vorzeichen je nach **Ablenkrichtung** des Profils.)
#
# **d) Axialkraft $$R_x$$** (Impulssatz, Flächenkräfte durch Druck)
# In **x-Richtung** ergibt sich für eine Teilung $$t$$ und Breite $$b$$:
# $$\boxed{\,R_x = b\,t\,(p_2 - p_1)\,}$$
# (**Interpretation:** Bei $$p_2>p_1$$ wirkt die resultierende Kraft in +x-Richtung auf das Gitter.)
#
# ---
#
# ### **Aufgabe 2: Springbrunnen mit Tank & Pumpe**
#
# **Gegeben:** Fontänenhöhe $$h_s$$, Tankspiegel $$h_0$$, Durchmesser $$d_I, d_{II}, d_2$$, Umgebungsdruck $$p_u$$, **alle** Verlustbeiwerte $$\zeta_i$$.
# **Gesucht:** a) Düsenaustrittsgeschwindigkeit $$v_2$$, b) Tanküberdruck $$p^\*$$, c) neue Höhe $$h_{s,\mathrm{neu}}$$ bei Loch ($$p^\*=0$$) + **Zusatz:** erforderliche Pumpendruckerhöhung.
#
# **a) Düsenaustrittsgeschwindigkeit $$v_2$$**
# Bernoulli vom Düsenmund bis zum Scheitelpunkt der Fontäne ($$v\approx 0$$, $$p=p_u$$):
# $$\boxed{\,v_2 = \sqrt{2 g h_s}\,}$$
#
# **b) Erforderlicher Tanküberdruck $$p^\***
# Bernoulli vom Tankspiegel ($$p^\*,\, h_0,\, v\approx 0$$) bis zur Atmosphäre am Scheitel ($$p_u,\, h_s,\, v\approx 0$$), inkl. **Verluste** in Zulauf (I), Rücklauf (II) und Düse:
# $$\;p^\* + \rho g h_0 = p_u + \rho g h_s + \tfrac12 \rho \left(\zeta_{\mathrm{ges},I} v_I^2 + \zeta_{\mathrm{ges},II} v_{II}^2 + \zeta_2 v_2^2\right)$$
# Damit:
# $$\boxed{\,p^\* = p_u + \rho g (h_s - h_0) + \tfrac12 \rho \left(\zeta_{\mathrm{ges},I} v_I^2 + \zeta_{\mathrm{ges},II} v_{II}^2 + \zeta_2 v_2^2\right)\,}$$
# Die **Teilgeschwindigkeiten** folgen aus der Kontinuität über die jeweiligen Querschnitte (z.B. $$v_I = \dot V/A_I$$, $$\dot V = A_2 v_2$$).
#
# **c) Loch im Tank → $$p^\*=0$$, $$h_0$$ konstant (Pumpe regelt Spiegel)**
# - **Ohne Verluste** ergäbe sich aus Bernoulli: $$\;h_{s,\mathrm{neu}} = h_0$$.
# - **Mit Verlusten** fällt Energie auf dem Weg zur Düse ab ⇒ $$\;h_{s,\mathrm{neu}} < h_0$$.
# **Qualitativ** ist die Fontäne **niedriger** als der Tankspiegel und deutlich **niedriger** als zuvor (mit Überdruck).
#
# **Zusatz:** Erforderliche **Pumpendruckerhöhung** $$\Delta p_\mathrm{P}$$ (um Betrieb zu halten)
# $$\boxed{\,\Delta p_\mathrm{P} = \big[p_u + \rho g (h_s - h_0) + \tfrac12 \rho (\zeta_{\mathrm{ges},I} v_I^2 + \zeta_{\mathrm{ges},II} v_{II}^2 + \zeta_2 v_2^2)\big] - p^\*\,}$$
# Setzt man $$p^\*=0$$ (Loch), liefert die Pumpe genau den zuvor fehlenden **Tanküberdruck** plus die **Verluste**.

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #2ecc71;">

# %% [markdown]
# ## ✅ Typische Stolpersteine & Tipps
# - **Bernoulli nur entlang eines Stromfadens** und **ohne** Wellen-/Shaftarbeit anwenden; **Verluste** korrekt addieren.
# - **Reynoldszahl**: richtige charakteristische Länge verwenden (z.B. Sehnenlänge am Flügel).
# - **Impulssatz**: **Richtungskosinus/Normalenrichtungen** sauber beachten; **Druckkräfte** über Randflächen korrekt bilanzieren.
# - **Schubspannung**: bei Newton’schen Fluiden linear in $$\mathrm{d}u/\mathrm{d}y$$; Wandgradient entscheidet über $$\tau_w$$.
# - **Turbomaschinen**: Vorzeichenkonventionen von $$c_u$$ und $$Y$$ (Euler-Gleichung) konsequent durchhalten.

# %% [markdown]
# <hr style="border: none; border-top: 5px solid #3498db;">
